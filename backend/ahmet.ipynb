# %%
# %load_ext autoreload
# %autoreload 2

# %%
from senti_ai.ml_logic.data import save_data_to_bq
from senti_ai.ml_logic.data import load_data_from_bq
import pandas as pd
from google.cloud import bigquery
from senti_ai.api.fast import get_historical, get_pred

# %%
GCP_PROJECT = "supple-folder-448412-n9"
BQ_DATASET = "sentiai"
TABLE = "raw" # we have tables 'raw' and 'processed' at the moment

# %%
df = get_historical(GCP_PROJECT, BQ_DATASET, "raw")
# Out:
# /Users/ahmetcakan/.pyenv/versions/3.10.6/envs/senti_ai/lib/python3.10/site-packages/google/cloud/bigquery/table.py:1900: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
df = get_pred()

# %%
df
# Out:
#          date     close
# 0  2025-03-13  68675.53
# 1  2025-03-14  68485.62
# 2  2025-03-15  69372.77
# 3  2025-03-16  71485.91
# 4  2025-03-17  71151.13
# 5  2025-03-18  70817.95
# 6  2025-03-19  73054.68
# 7  2025-03-20  74175.98
# 8  2025-03-21  73479.50
# 9  2025-03-22  74276.84
# 10 2025-03-23  73588.42
# 11 2025-03-24  72902.97
# 12 2025-03-25  73255.77
# 13 2025-03-26  70452.59
# 14 2025-03-27  68022.09
# 15 2025-03-28  67257.13
# 16 2025-03-29  65894.73
# 17 2025-03-30  66308.88
# 18 2025-03-31  65104.68
# 19 2025-04-01  63265.72
# 20 2025-04-02  65120.23
# 21 2025-04-03  64826.18
# 22 2025-04-04  64913.73
# 23 2025-04-05  63064.02
# 24 2025-04-06  62377.40
# 25 2025-04-07  62515.78
# 26 2025-04-08  61076.67
# 27 2025-04-09  61535.60
# 28 2025-04-10  60796.39
# 29 2025-04-11  60441.71
